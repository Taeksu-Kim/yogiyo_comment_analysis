# %%
import os 
import re 
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
import urllib.request as ur
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

from konlpy.tag import Twitter  
from collections import Counter

import tensorflow as tf
import torch

from transformers import BertTokenizer
from transformers import BertForSequenceClassification, AdamW, BertConfig
from transformers import get_linear_schedule_with_warmup
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

import random
import datetime

from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
import nltk 
from nltk.corpus import stopwords
import matplotlib
from IPython.display import set_matplotlib_formats
from wordcloud import WordCloud

# %%
# 입력 데이터 변환
def convert_input_data(sentences):

    # BERT의 토크나이저로 문장을 토큰으로 분리
    tokenized_texts = [tokenizer.tokenize(sent) for sent in sentences]

    # 입력 토큰의 최대 시퀀스 길이
    MAX_LEN = 128

    # 토큰을 숫자 인덱스로 변환
    input_ids = [tokenizer.convert_tokens_to_ids(x) for x in tokenized_texts]
    
    # 문장을 MAX_LEN 길이에 맞게 자르고, 모자란 부분을 패딩 0으로 채움
    input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", truncating="post", padding="post")

    # 어텐션 마스크 초기화
    attention_masks = []

    # 어텐션 마스크를 패딩이 아니면 1, 패딩이면 0으로 설정
    # 패딩 부분은 BERT 모델에서 어텐션을 수행하지 않아 속도 향상
    for seq in input_ids:
        seq_mask = [float(i>0) for i in seq]
        attention_masks.append(seq_mask)

    # 데이터를 파이토치의 텐서로 변환
    inputs = torch.tensor(input_ids)
    masks = torch.tensor(attention_masks)

    return inputs, masks

# %%
# 문장 테스트
def test_sentences(sentences):

    # 평가모드로 변경
    model.eval()

    # 문장을 입력 데이터로 변환
    inputs, masks = convert_input_data(sentences)

    # 데이터를 GPU에 넣음
    b_input_ids = inputs.to(device)
    b_input_mask = masks.to(device)
    
    b_input_ids = torch.tensor(b_input_ids).to(device).long()
            
    # 그래디언트 계산 안함
    with torch.no_grad():     
        # Forward 수행
        outputs = model(b_input_ids, 
                        token_type_ids=None, 
                        attention_mask=b_input_mask)
        

    # 로스 구함
    logits = outputs[0]

    # CPU로 데이터 이동
    logits = logits.detach().cpu().numpy()

    return logits

# %%
browser = webdriver.Chrome("C:/jupyter/chromedriver.exe")


browser.get("https://www.yogiyo.co.kr/mobile/#/13338/")

# browser.get("https://www.yogiyo.co.kr/mobile/#/469202/")

browser.maximize_window()
time.sleep(2)
elem = browser.find_element_by_xpath("//*[@id='content']/div[2]/div[1]/ul/li[2]/a")
elem.click()

elem = browser.find_element_by_xpath("//*[@id='review']/li[12]")

# 화면 가장 아래로 스크롤 내리기
browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")

interval = 2 # 2초에 한번씩 스크롤 내림

# 현재 문서 높이를 가져와서 저장
prev_height = browser.execute_script("return document.body.scrollHeight")

# 반복 수행
while True:
    # 스크롤을 가장 아래로 내림
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    try:
        elem.click()
    except:
        pass
    
    # 페이지 로딩 대기
    time.sleep(interval)


    # 현재 문서 높이를 가져와서 저장
    curr_height = browser.execute_script("return document.body.scrollHeight")
    if curr_height == prev_height:
        break

    prev_height = curr_height

print("스크롤 완료")
# Out:
# 스크롤 완료

# %%
soup = bs(browser.page_source, "lxml")
# page_source로 스크롤 끝까지 내렸을 때의 html 정보를 가져오게 됨

# 정보) 속성을 리스트로 감싸주어 조건을 만족하는 모든 데이터를 가져올 수 있다.
# reviews = soup.find_all("div", attrs={"class":["ImZGtf mpg5gc", "Vpfmgd"]})
reviews = soup.find_all("li", attrs={"class": "list-group-item star-point ng-scope"})
print(len(reviews))
total_average = 0 # 리뷰 전체 평균
# %%
len(comments)
# Out:
# 228

# %%
comments[0]
# Out:
# '오랜만에 시켰는데 맛이 예전같찌 않네요~\n홍합은 국물이 다 새서 왔어요~ㅜ'

# %%
# twitter = Twitter()
twitter = Twitter() 
morphs = [] 
for sentence in comments: 
    morphs.append(twitter.pos(sentence)) 
    
print(morphs)
# Out:
# C:\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# [[('오랜', 'Modifier'), ('만', 'Noun'), ('에', 'Josa'), ('시켰는데', 'Verb'), ('맛', 'Noun'), ('이', 'Josa'), ('예전', 'Noun'), ('같', 'Adjective'), ('찌', 'Noun'), ('않네요', 'Verb'), ('~', 'Punctuation'), ('\n', 'Foreign'), ('홍합', 'Noun'), ('은', 'Josa'), ('국물', 'Noun'), ('이', 'Josa'), ('다', 'Adverb'), ('새서', 'Verb'), ('왔어요', 'Verb'), ('~', 'Punctuation'), ('ㅜ', 'KoreanParticle')], [('여태', 'Noun'), ('까지', 'Josa'), ('먹던', 'Verb'), ('중', 'Noun'), ('최고', 'Noun'), ('로', 'Josa'), ('맛없어', 'Adjective'), ('다', 'Adverb'), ('버려', 'Verb'), ('버렷', 'Noun'), ('어', 'Suffix'), ('요', 'Josa')], [('뷔페', 'Noun'), ('가면', 'Noun'), ('먹을', 'Verb'), ('수', 'Noun'), ('있는', 'Adjective'), ('족발', 'Noun'), ('맛', 'Noun'), ('입니다', 'Adjective'), ('하지만', 'Conjunction'), ('족발', 'Noun'), ('빼고는', 'Verb'), ('다', 'Adverb'), ('맛있었습니다', 'Adjective')], [('중', 'Noun'), ('짜리', 'Verb'), ('3', 'Number'), ('명', 'Noun'), ('이', 'Josa'), ('머꼬', 'Noun'), ('도', 'Josa'), ('남았어요', 'Verb'), ('...', 'Punctuation'), ('가격', 'Noun'), ('도', 'Josa'), ('착하구', 'Adjective'), ('맛', 'Noun'), ('도', 'Josa'), ('정', 'Noun'), ('갈', 'Verb'), ('깔끔하네요', 'Adjective'), ('...', 'Punctuation'), ('보쌈', 'Noun'), ('고', 'Josa'), ('기도', 'Noun'), ('퍽퍽', 'Noun'), ('하', 'Suffix'), ('거나', 'Noun'), ('비계', 'Noun'), ('가', 'Josa'), ('만', 'Noun'), ('커나', 'Verb'), ('하지', 'Verb'), ('않구', 'Verb'), ('비율', 'Noun'), ('이', 'Josa'), ('딱', 'Adverb'), ('조으네요', 'Adjective'), ('..', 'Punctuation'), ('보쌈', 'Noun'), ('하면', 'Verb'), ('생각날꺼', 'Verb'), ('같아요', 'Adjective')], [('잘', 'VerbPrefix'), ('먹어서요', 'Verb'), ('혼자', 'Noun'), ('먹기', 'Noun'), ('모', 'Noun'), ('잘라지도', 'Verb'), ('않아서요', 'Verb')], [('맛있게', 'Adjective'), ('잘', 'VerbPrefix'), ('먹었습니다', 'Verb')], [('맛있게', 'Adjective'), ('잘', 'Verb'), ('먹었습니다', 'Verb')], [('배달', 'Noun'), ('이', 'Josa'), ('늦게왓', 'Noun'), ('지만', 'Josa'), ('맛', 'Noun'), ('은', 'Josa'), ('조앗어요', 'Adjective'), ('.', 'Punctuation'), ('막국수', 'Noun'), ('양념', 'Noun'), ('은', 'Josa'), ('맛', 'Noun'), ('잇는데', 'Verb'), ('면', 'Noun'), ('에서', 'Josa'), ('냄새', 'Noun'), ('가', 'Josa'), ('좀나네요', 'Adjective')], [('와', 'Verb'), ('ㅠㅠ', 'KoreanParticle'), ('이', 'Determiner'), ('가격', 'Noun'), ('이', 'Josa'), ('이', 'Determiner'), ('구성', 'Noun'), ('이', 'Josa'), ('!??!??', 'Punctuation')], [('맛있어요', 'Adjective'), ('~~~~~~', 'Punctuation')], [('음식', 'Noun'), ('맛', 'Noun'), ('과', 'Josa'), ('양은', 'Noun'), ('만족하였으나', 'Adjective'), ('배달', 'Noun'), ('원', 'Suffix'), ('의', 'Josa'), ('서비스', 'Noun'), ('착오', 'Noun'), ('로', 'Josa'), ('좀', 'Noun'), ('아쉬운', 'Adjective'), ('점', 'Noun'), ('은', 'Josa'), ('있었습니다', 'Adjective')], [('배달', 'Noun'), ('이', 'Josa'), ('넘', 'Verb'), ('늣', 'Noun'), ('네', 'Suffix'), ('여', 'Josa'), ('저', 'Determiner'), ('시', 'Modifier'), ('갓', 'Modifier'), ('애', 'Noun'), ('안오고', 'Verb')], [('음', 'Noun'), ('..', 'Punctuation'), ('약간', 'Noun'), ('맛', 'Noun'), ('이', 'Josa'), ('밍밍', 'Noun'), ('했어요', 'Verb')], [('새우젓', 'Noun'), ('주심', 'Noun'), ('조을텐대', 'Adjective')], [('냄새', 'Noun'), ('안나', 'Noun'), ('요', 'Josa'), ('양도', 'Noun'), ('괜찮아요', 'Adjective')], [('맛', 'Noun'), ('은', 'Josa'), ('괜', 'Noun'), ('찬은데', 'Verb'), ('상추', 'Noun'), ('가', 'Josa'), ('잘', 'VerbPrefix'), ('안', 'VerbPrefix'), ('씻어', 'Verb'), ('젔', 'Noun'), ('네', 'Suffix'), ('요', 'Josa')], [('쟁반', 'Noun'), ('국수', 'Noun'), ('가', 'Josa'), ('맛있어서', 'Adjective'), ('항상', 'Noun'), ('여기', 'Noun'), ('서', 'Josa'), ('주문', 'Noun'), ('해요', 'Verb'), ('\n', 'Foreign'), ('보쌈', 'Noun'), ('도', 'Josa'), ('족발', 'Noun'), ('도', 'Josa'), ('항상', 'Noun'), ('맛있는데', 'Adjective'), ('이번', 'Noun'), ('보쌈', 'Noun'), ('은', 'Josa'), ('좀', 'Noun'), ('퍽퍽', 'Noun'), ('한식', 'Noun'), ('감', 'Noun'), ('이라서', 'Josa'), ('아쉬웠습니다', 'Adjective')], [('배달', 'Noun'), ('은', 'Josa'), ('좀', 'Noun'), ('늦었지만', 'Verb'), ('맛', 'Noun'), ('은', 'Josa'), ('있었어요', 'Adjective'), ('.', 'Punctuation')], [('정말', 'Noun'), ('맛있습니다', 'Adjective'), ('!', 'Punctuation'), ('명품', 'Noun'), ('장충동', 'Noun'), ('외', 'Noun'), ('에는', 'Josa'), ('안', 'VerbPrefix'), ('시켜', 'Verb'), ('먹어요', 'Verb')], [('보쌈', 'Noun'), ('은', 'Josa'), ('김치', 'Noun'), ('맛', 'Noun'), ('으로', 'Jos ...

# %%
filter_words = ["다만", "껀", "먹기", "전체", "한지", "온", "생각", "별로", "맛", "배달", "도", "애", "두", "앞", "용", "때", "무조건", "좀", "꼭", "아주", "일단", "원래", "또", "것", "내", "나", "수", "게", "말", "진짜", "제일", "최고", "처음", "것", "정말", "이벤트", "매우", "번", "그냥", "이용"]

noun_adj_adv_list=[]

for sentence in morphs : 
    for word, tag in sentence : 
        if tag in ['Noun'] and word not in filter_words: 
            noun_adj_adv_list.append(word) 
            
print(noun_adj_adv_list)

# noun_adj_adv_list=[] 

# for sentence in morphs : 
#     for word, tag in sentence : 
#         if tag in ['Noun'] and ("꼭" not in word) and ("담" not in word) and ("이벤트" not in word) and ("원래" not in word) and ("역시" not in word) and ("곳" not in word) and ("오늘" not in word) and ("더" not in word) and ("진짜" not in word) and ("또" not in word) and ("다음" not in word) and ("제일" not in word) and ("항상" not in word) and ("처음" not in word) and ("좀" not in word) and ("것" not in word) and ("내" not in word) and ("나" not in word)and ("수"not in word) and("게"not in word)and("말"not in word): 
#             noun_adj_adv_list.append(word) 
            
# print(noun_adj_adv_list)
# Out:
# ['만', '예전', '찌', '홍합', '국물', '여태', '중', '버렷', '뷔페', '가면', '족발', '족발', '중', '명', '머꼬', '가격', '정', '보쌈', '기도', '퍽퍽', '거나', '비계', '만', '비율', '보쌈', '혼자', '모', '늦게왓', '막국수', '양념', '면', '냄새', '가격', '구성', '음식', '양은', '서비스', '착오', '점', '늣', '음', '약간', '밍밍', '새우젓', '주심', '냄새', '안나', '양도', '괜', '상추', '젔', '쟁반', '국수', '항상', '여기', '주문', '보쌈', '족발', '항상', '이번', '보쌈', '퍽퍽', '한식', '감', '명품', '장충동', '외', '보쌈', '김치', '김치', '덜', '예전', '분도', '만해', '리뷰', '보고', '다음', '여기', '신분', '시크', '문', '한마디', '안', '이틀', '연속', '주문', '정도', '족발', '보쌈', '가성', '비', '갑', '짱', '어디', '집', '김치', '굴', '보고', '저희', '아빠', '셧', '김치', '여기', '주문', '생겻어', '양도', '만족', '족발', '보쌈', '운', '여기', '갑', '빼', '전부', '빼', '주심', '감덩', '영', '족발', '냄새', '기분', '주문', '더', '음식', '양', '좀더', '항상', '양', '항상', '여기', '만', '다음', '조금', '항상', '리얼', '양', '사진', '막', '넉', '담', '겨', '그', '항상', '양은', '할인', '주문', '무가', '썻어', '정도', '가격', '가성', '비', '조쿠', '가조', '쿠', '보', '이루', '양도', '양도', '림', '곳', '개인', '네', '다음', '막국수', '보쌈', '족발', '껍데기', '쫌', '편', '보쌈', '자리', '켯', '양도', '둘', '김치', '항상', '여기', '번창', '기도', '쟁반', '국수', '김치', '굴', '구', '캠핑장', '보쌈', '여기', '항상', '곳', '기도', '명', '양', '밥', '양도', '항상', '비빔', '막국수', '요', '매번', '보쌈', '주문', '족발', '옴', '지경', '역시', '막국수', '런가', '짱', '만
'주문', '분만', '작성', '클린', '리뷰', '제공', '자체', '검열', '때문', '아르바이트생', '작성', '경우', '점', '음식', '대해', '더', '평가', '업체', '참고', '개선', '말씀', '전달', '족발', '주문', '취소', '오냐', '양', '단골', '집', '뭐', '안', '퍽퍽해', '굿', '선부동', '쪽', '족발', '여기', '리뷰', '평', '부침개', '부침개', '패스', '완전', '굿', '족발', '보쌈', '만하', '보쌈', '중', '특', '보쌈김치', '굴', '리뷰', '등록', '족발', '별룬데', '고기', '퍽퍽', '껍질', '쟁반', '국수', '맹맛', '고요', '보쌈', '부위', '항정살', '이', '느낌', '뭐', '부침개', '기름', '덩어리', '보쌈', '고기', '부위', '고기', '보쌈', '콜라', '주문', '왜', '자마자', '번호', '영업', '마감', '요', '매번', '양도', '모래', '입맛', '간반', '요기', '요가', '임', '두번째', '요', '무', '말랭이', '참고', '보쌈', '다른', '보쌈', '집', '고기', '부침개', '다음', '보쌈', '주문', '요기', '사장', '사업', '번창', '세트', '켯', '양도', '리뷰', '시간', '족발', '음식', ...

# %%
count = Counter(noun_adj_adv_list)

# %%
words = dict(count.most_common())

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
import nltk 
from nltk.corpus import stopwords
import matplotlib
from IPython.display import set_matplotlib_formats

# %%
# %matplotlib inline

import matplotlib
from IPython.display import set_matplotlib_formats
matplotlib.rc('font',family = 'Malgun Gothic')
set_matplotlib_formats('retina')
matplotlib.rc('axes',unicode_minus = False)

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(font_path = 'C:/Windows/Fonts/malgun.ttf', background_color='white',colormap = "Accent_r", width=1500, height=1000).generate_from_frequencies(words) 
plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()

# %%
def Sentiment_Analysis(list):
        # 디바이스 설정
    global device
    if torch.cuda.is_available():    
        device = torch.device("cuda")
        print('There are %d GPU(s) available.' % torch.cuda.device_count())
        print('We will use the GPU:', torch.cuda.get_device_name(0))
    else:
        device = torch.device("cpu")
        print('No GPU available, using the CPU instead.')
    global model    
    model = BertForSequenceClassification.from_pretrained("bert-base-multilingual-cased", num_labels=2)
    model.cuda()

    PATH = './'
    model.load_state_dict(torch.load(PATH + 'model_state_dict.pt'))

    global tokenizer
    tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased', do_lower_case=False)
    positive = []
    negative = []
    
    for i in list:
        logits = test_sentences([i])
        if np.argmax(logits) == 1:
            positive.append(i)
        elif np.argmax(logits) == 0:
            negative.append(i)
    return positive, negative

# %%
positive_comments, negative_comments = Sentiment_Analysis(comments)
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: GeForce GTX 1060 6GB
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <ipython-input-3-eb5b3de8f22e>:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   b_input_ids = torch.tensor(b_input_ids).to(device).long()

# %%
positive_comments
# Out:
# ['뷔페가면 먹을 수 있는 족발 맛입니다 하지만 족발 빼고는 다 맛있었습니다',
#  '중짜리 3명이 머꼬도 남았어요...가격도 착하구 맛도 정갈 깔끔하네요...보쌈고기도 퍽퍽하거나 비계가 만커나 하지않구 비율이 딱 조으네요..보쌈하면 생각날꺼 같아요',
#  '맛있게 잘먹었습니다',
#  '맛있게 잘 먹었습니다',
#  '맛있어요~~~~~~',
#  '배달이넘늣네여저시갓애안오고',
#  '새우젓 주심 조을텐대',
#  'ㅎㅎㅎㅎㅎㅎ맛잇어요!!!!!엄마가음식깔끔하게나온다고좋아하시네욤 ㅎㅎㅎ근데 족발이너무두껍게썰려있어서 ㅎㅎㅎ그거만아니면좋앗어용',
#  '진짜맛있어요ㅎ 오랜만에 진짜맛있는 보쌈배불리\n먹었습니다ㅎ 다음에 또주문할게요. 근데..배달하시는분이 좀 불친절하셨는데,\n음식은 엄지척?!👍',
#  '맛있습니다. 보쌈김치에 굴이 더 많이 들어가면 좋겠습니다~^^',
#  '동치미도 맛나고 무생채에 굴도 들어있고 족발도 맛나고 전체적으로 완전 만족합니다~ 담에 또 시켜먹을게요',
#  '김치양이좀적네요 그래도 맛있어요',
#  '참편리하고 좋았어요~',
#  '소 시켰는데 이렇게나 푸짐하게 왔어요 얼른 먹고싶어서 급하게 사진찍었는데 지금보니 다 흔들렸네요ㅋㅋㅋㅋ\n맛있습니당 쌈야채도 신선하구요 무엇보다 양념무채에 굴이 들어가 있어서 넘넘 좋았어요! 야식으로 딱입니다 번창하십쇼 사장님^^',
#  '맛있게 잘먹었습니다',
#  '1시간이넘었는데배달이안오네여ㅋ 결국오던지말던지 상관안하고 안기다리는즁ㅋ',
#  '푸짐하고 맛있네요..',
#  '저도 남편도 비계많은 부위를 싫어해서 보쌈고기는 좋았어요 배달은 딱 50분 넘어가니까  오시더라구욤. 막국수는 소스맛이 먼가 좀 부족했구요 머 일단 대략만족 입니다^^',
#  '보쌈은살짝 기름기가많지는하지만 맛있게잘묵었습니다',
#  '맛있게 잘먹었습니다',
#  '정성이가득하고 친절함,',
#  'ㅋ',
#  '맛냄새 잘느끼시면 드시지마시길바래요\n돼지 누린내  엄청 나네요',
#  '맛도 배달시간도 쵝오!!\n배달늦게온다는사람도있던데 우리집은와동이라그런가엄청빨리오셔서 배달해주시는아저씨보고 깜놀..\n근데 살코기는안먹는편이라 메뉴가 미니족도있었으면\n정말좋겠다는...',
#  'ㄴ',
#  '맛잇게잘먹엇습니당',
#  '족발 나름 괜찮았어요~\n냄새도안나고 양도 적당하고 잘먹었습니다~',
#  '괜차늠',
#  '맛있어요',
#  '好吃好吃好吃...',
#  '굿',
#  '선부동쪽 족발은 여기가 나은듯',
#  '好吃好吃好吃',
#  '굿!!!',
#  '족발보다는 보쌈이먹을만하네',
#  '好吃好吃好吃',
#  '보쌈 중짜리시켰는데 특중짜리왔네요 보쌈김치에 \n굴까지...  너무 만족해서 처음 리뷰등록합니다',
#  '매번 시켜먹는데 맛Good 양도 Goog',
#  '먹을만했는데모래가씹혀서ㅡㅡ입맛버림',
#  '두번째 배달 넘맛나요^^',
#  '맛났오여!!!',
#  '很好吃...',
#  '平时都还算快，今天有点慢...',
#  '很好吃...很赞...good',
#  '리뷰대로 배달시간은 느리내요 ㅎㅎ 하지만 족발과 다른음식은 먹을만하내요 ㅎㅎ',
#  'good',
#  'good',
#  '깔끔하고 괜찮네요~~.!',
#  '배달빠르네요ㅎㅎ',
#  '배달도 빠르고 고기도 부드럽고 맛잇네요ㅎㅎ',
negative_comments
# Out:
# ['오랜만에 시켰는데 맛이 예전같찌 않네요~\n홍합은 국물이 다 새서 왔어요~ㅜ',
#  '여태까지 먹던중최고로 맛없어 다 \n버려버렷어요',
#  '잘먹어서요 혼자먹기 모잘라지도않아서요',
#  '배달이 늦게왓지만 맛은 조앗어요.막국수 양념은 맛잇는데 면에서 냄새가좀나네요',
#  '와 ㅠㅠ  이가격이 이구성이!??!??',
#  '음식맛과 양은 만족하였으나 배달원의 서비스착오로 좀 아쉬운점은 있었습니다',
#  '음..약간맛이밍밍했어요',
#  '보쌈은 김치맛으로 먹는데\n김치가 덜 맛있었어요\n배달은 35분 걸려어요',
#  '너무 맛없어요... 예전이랑 맛이좀 다른듯....',
#  '리뷰보고 처음시켰는데 맛나네요~\n다음에도 여기에서 시킬꺼같아요^^',
#  '족발에서 냄새가 나요... 우울해서 기분풀려고 주문했는데 더 우울하네요....',
#  '맛은 좋았구요^^ 양을 좀더 늘려주시면 좋을것 같습니다',
#  '처음시켜먹었는데 다음에도',
#  '너무찔겨서 그져그래요',
#  '맛 양은 좋았으나 배달이 1시간 20분',
#  '아 이정도가격에 이맛이면 가성비가 조쿠요 가조쿠 보이루!',
#  '그렇게 먹고싶진않내요 배달특히 개느림 다른곳에서 먹을래요 걍',
#  '개인적으로 맛이 별로엿네요...ㅜㅜ',
#  '너무늦게옴 짜증날지경..;',
#  '아니 밥 3개를 시켰는데 실수로 하나만 가져다 주지를 않나.. 상추에서 벌레가 나오지를 않나.. 무공해 상추라 그렇다고 김치 많이드렸으니 김치에다 싸서 드시라는데 진심 할 말을 잃었네요ㅎ 네.. 시켜드실 분들은 시켜드세요..ㅎ',
#  '딱 보쌈만 맛있어요ㅠ\n청상추는 다 병기가 있어서 쌈해서먹을수가 없었어요.ㅠ\n돈 아까워',
#  '대짜리 시켰는데 양이 대짜가 아닌거같네요..... 가끔족발 시켜서먹는데 보쌈은 아닌거같네여;;',
#  '깔끔해요',
#  '맛괜찮아서여기서자주시켜먹었는데\n점점맛없어짐\n이번엔최악이엿음..\n다신안시킴',
#  '배달을 잘못가서 1시간 넘어서받았어요 족발 굵기도 일정하시안고 조금많이실망했네요',
#  '두시간이 다되도 안와요\n별점도 아까워요. 성질나요',
#  '무난해여',
#  '족발은  점심때 만들어서 식혀놓은신것인지\n쫄깃한 식감은 좋은나  뭐라고 해야지~~싱거운맛\n삶을때 양념이 안베인거같은느낌\n쟁반국수도 양념이 너무없고 그냥 보통 평범한맛이였어요',
#  '저번에한번먹어보구\n맛있어서또시켯는데\n오늘은완전..ㅡㅡ전은기름에쩔어있고...고기냄새나고두껍고..보쌈김치도맛없고...배달은1시간걸림...',
#  '음식이도착은안함1시간30분지남',
#  '모래십혀요\n상추에서 나오는줄알았는데\n족발에서도 십히네요\n최악',
#  '주문한지 한시간째 일요일이라 늦는다고 하는데\n이건 기다리다 미칠듯\n리뷰보고 주문해야하는데 그냥 주문했다 피보네요\n시간 많으신분만 주문하길\n아직 맛도 못 보았네요.',
#  '시킨지 50분넘었는데  대체 언제와여..\n배고픈데 언제와요 오긴오나요😥\n돼지 잡으러가셨나요 언제오시나요\n다음부터 안시킬게요 시킨거라도 오게 해주세요',
#  '맛있는데... 배달속도가 느리네요',
#  '명품은 짝퉁만도못하네요 음식 제대로만들고 장사하세요',
#  '좀늦긴 했지만 맛나긴하네요',
#  '배달이 너무 느리네요 한시간이 뭡니까',
#  '개인적으로 쫄면은 별로였소\n큰뼈도 자르지말고 그냥 두는 편이\n야무지게 뜯어먹을수있어 좋았는데',
#  '맛있어요!! 하지만...배달이 1시간 10분 걸립니다...',
#  '좋아요~',
#  '좋아요~',
#  '보쌈먹는게  한시가넘게  기다렸다,그나마  맛은  괜찬아서   다행이네요',
#  '다른거 다 떠나서 너무 늦네요..\n1시간정도 걸렸습니다.',
#  '주문을 30분 전에 햇는데 연락이 없는건 뭐죠',
#  '알바생이너무많네여..댓글다시는알바분 ㅜ\n\n[요기요]안녕하세요, 고객님. 저희 요기요는 음식을 주문하신 분만 작성 가능한 클린 리뷰를 제공하고 있고, 자체적으로 검열을 하고 있기 때문에 아르바이트생이 작성을 하는 경우는 없는 점 안내드립니다. 음식에 대해 좀 더 자세한 평가를 해주신다면 업체에서도 참고하여 개선하도록 하겠다는 말씀 전달해드립니다. 감사합니다.',
#  '족발이 식어서 오네요 ..비린내가 나고  배달이 너무 늦어 주문 취소하고 싶네요',
#  '언제오냐?',
#  '생각보다 양이많네요',
#  '단골집이라 뭐 특별히...',
#  '다신 안 먹어 ㅡㅡ 너무 맛없고 퍽퍽해여',
#  '리뷰평 좋아서 시켜 먹어봤는데 맛있네요ㅋ\n부침개에서 쉰맛이좀 나길래 부침개는 패스',
#  '시켜먹지 마라요 완전 짜증남',
#  '그냥그럭저럭',
#  '족발 별룬데요 고기는 퍽퍽하고 껍질은 야들야들하지 않아요쟁반국수도 맹맛이고요 배달은 빨라요 30분',
#  '보쌈은 고기부위가 따로있는데\n항정살같은 이 느낌은 뭐죠...\n부침개도 기름 덩어리...\n보쌈고기가 아니라\n다른부위의 고기를 먹은 느낌이였어요.\n보쌈먹고싶어서 시킨건데 이상했음.',
#  '콜라 1.25주문했는데 왜 500 짜리 가져다주시나요? 배달오자마자 전화하려니 번호도없고 영업마감이네요!',
#  '맛은잇는데 배달한시간반걸림ㄷㄷ요기요가 느리오임',
#  '맛있는데 무말랭이는 없어요 참고하시기 바랍니다',
#  '보쌈을시켰는데 배달이  오래걸린다는걸빼면 다른 보쌈집보다 훨씬 맛나네요\n고기 누린내도없구 부침개?두 너무맛있었어요\n다음부터  보쌈주문은 요기로 해야겠어요!\n사장님 사업 번창하시구요 배달만 좀 빨리 부탁드려요~^^',
#  '..',
#  '정말 왔어... 30분만에 ㅎㅎㅎ\n2만원 세트 시켯는데 양도 적당하고 갠찬앗음',
#  '언제먹어도맛이써',
#  '맛은 있으나 배송이 너무 오래 걸림 장난 같이 먹을려고 밥하고 된장 찌게 끓여 노은거 다시 뎁혔네요...',
#  '보쌈을 시켰어요 맛은 있는데 배달은 너무 늦었어요\n한시간이나 걸리고 전화받는 분은 너무나도 당당하게 지금 곧 가요 저녁시간이라서 늦어서 죄송합니다 이럽니다\n배달이 너무 늦어요',
#  '1시간 20분 걸려서 온 족발 대자 치곤 양도 적고 마늘은 \n다 말라 비틀어졌고 메인요리인 족발은 차갑고 군데군데\n기름이 하얗게 껴있고  젤 먹을만햇던건 막국수 하나뿐이네요  담엔 막국수만 시켜야겠어요 별점 -는 없나??\n리뷰 꼼꼼히 읽고 시켜야지 이거원... 음식앞에서 인상만쓰네',
#  '부수적인건 많고 맛있는데 정작 족발이....맛이 없네요.',
#  '완전 별로임 .... 다신 족발먹고 싶지가 않내요',
#  '주문취소해주세요',
#  '정말편해요^^',
#  '배달 겁나 느리네',
#  '맞도없구  배달도 한시간 넘구...넘하내요\n오늘  처음인디..',
#  '음.. 저녁에시켜서그런지 맛은괜찮은데 식었다못해 차가웠고요\n뭐.. 별3개정도되는거같습니다 맛은',
#  '맛나요~~',
#  '이건아니지',
#  '아나~..!!  저번보더 배달이 더 늦어지네요...\n저번엔 소요시간 40분 이라더니 50분에 오고 오늘도 40분 이라더니...한시간...소요시간을 띄우지 말던가..',
#  '굿~~~',
#  '8시40분에 주문햇는데 지금 9시 45분 넘엇는데 왜 배달이 안오는거?? 소요시간 35분이아며 ㅡㅡ 게다가 전화번호를 알수가 없어서 114에 전화햇더니 전화번호도 없내 ㅡㅡ 어쩌라는거지??',
#  '먹을만하네요',
#  '저번보다는배달도늦고보쌈을시켰는데김치에있는굴에서는비린내나고보쌈고기는좀느끼하네요...',
#  '족발을시켰는느끼하지도않고냄새도않나고맛있게잘먹었어요...중으로시컸는데양이너무많아서다못먹었네요...다음에기회돼면또시킬게요...',
#  '맛 없어요 ᆢ']

# %%
def make_wordcloud(list):
    twitter = Twitter() 
    morphs = [] 
    for sentence in list: 
        morphs.append(twitter.pos(sentence))

    
    filter_words = ["다만", "껀", "먹기", "전체", "한지", "온", "생각", "별로", "맛", "배달", "도", "애", "두", "앞", "용", "때", "무조건", "좀", "꼭", "아주", "일단", "원래", "또", "것", "내", "나", "수", "게", "말", "진짜", "제일", "최고", "처음", "것", "정말", "이벤트", "매우", "번", "그냥", "이용"]
    noun_adj_adv_list=[]

    for sentence in morphs : 
        for word, tag in sentence : 
            if tag in ['Noun'] and word not in filter_words: 
                noun_adj_adv_list.append(word) 
                
    count = Counter(noun_adj_adv_list)
    words = dict(count.most_common())
    
    matplotlib.rc('font',family = 'Malgun Gothic')
    set_matplotlib_formats('retina')
    matplotlib.rc('axes',unicode_minus = False)
    
    wordcloud = WordCloud(font_path = 'C:/Windows/Fonts/malgun.ttf', background_color='white',colormap = "Accent_r", width=1500, height=1000).generate_from_frequencies(words) 
    plt.imshow(wordcloud) 
    plt.axis('off') 
    return plt.show()

# %%
make_wordcloud(positive_comments)

# %%
make_wordcloud(negative_comments)

# %%
make_wordcloud(comments)
